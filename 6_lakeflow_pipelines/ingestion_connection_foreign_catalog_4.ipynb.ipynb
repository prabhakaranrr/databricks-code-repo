# %%
# %python
#Decorator in Python
def add_accessories(f_sendcar):
    def wrapper():
        print("3M will decorate your car")
        f_sendcar()
        print("3M have decorated your car")
    return wrapper

@add_accessories
def car():
    #cost=100000
    print("Prabhakaran purchased a new car without decoration")

car()

# %%
# %python
#Decorator in Python
#Declarative pipeline (DP)
def add_accessories(f_sendcar):
    def wrapper():
        print("Declarative programming - Dataquality, Datalineage, Governance, CDC, CDF, SCD, Materialize....")
        f_sendcar()
        print("Declarative programming - Dataquality, Datalineage, Governance, CDC, CDF, SCD, Materialize....")
    return wrapper

@add_accessories
def car():
    #cost=100000
    print("We wrote spark program Imperatively (Procedural Programming)")
car()

# %% [markdown]
# ###Foreign Catalog Connection
# A Foreign Catalog is a Unity Catalog object that allows Databricks to reference and query metadata that lives outside Databricks, in an external metastore or database, without copying the data.<br>
# Databricks can securely access an external database (Google Cloud SQL) using Unity Catalog–managed connections and foreign catalogs, without ingesting or copying the data.
#
# **Use Foreign Catalog when:**
# - Ad-hoc analysis
# - Alternative for Custom JDBC or 3rd party connectors (for data copy)
# - Incremental Ingestion (I just need only data from yesterday)
# - No need to persist data (If we only want to refer/lookup)
# - Real-time lookup (If any changes made in source DB, will be reflected)
# - Avoid data duplication (Acts like a shallow copy (without snapshot))

# %% [markdown]
# ![](/Workspace/Users/prabhakaranrr@gmail.com/databricks-code-repo/6_lakeflow_pipelines/connection_foreign_catalog.png)

# %% [markdown]
# **Source DB Side**
# CREATE TABLE shipments (
#     shipment_id INT PRIMARY KEY,
#     first_name  VARCHAR(50),
#     last_name   VARCHAR(50),
#     age         INT,
#     role        VARCHAR(50),
#     insert_ts   TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#     update_ts   TIMESTAMP DEFAULT CURRENT_TIMESTAMP);
#
#   INSERT INTO shipments
#     (shipment_id, first_name, last_name, age, role)
#     VALUES
#     (5000001, 'Rajesh',  'Kumar', 35, 'Driver'),
#     (5000002, 'Anita',   'Sharma',29, 'Dispatcher'),
#     (5000003, 'Michael', 'Chen',  41, 'Warehouse Manager'),
#     (5000004, 'Suresh',  NULL,    52, 'Loader'),
#     (5000005, 'Priya',   'Iyer',  27, 'Analyst');

# %% [markdown]
# MySQL (shipments table)-  (Foreign Catalog) - Databricks (External Table (foreign catalog)) -> CDC Filter (insert_ts / update_ts) -> Bronze Delta Table

# %% [markdown]
# ####1. Source DB Readiness
#
# **Create the following table in source Database**
#     create database if not exists logistics;
#
#     CREATE TABLE logistics.shipments (
#       shipment_id INT PRIMARY KEY,
#       first_name  VARCHAR(50),
#       last_name   VARCHAR(50),
#       age         INT,
#       role        VARCHAR(50),
#       updated_at  TIMESTAMP DEFAULT CURRENT_TIMESTAMP
#     );
#
# INSERT INTO logistics.shipments VALUES
# (5000001,'Rajesh','Kumar',35,'Driver',CURRENT_TIMESTAMP),
# (5000002,'Anita','Sharma',29,'Dispatcher',CURRENT_TIMESTAMP),
# (5000003,'Michael','Chen',41,'Warehouse Manager',CURRENT_TIMESTAMP),
# (5000004,'Suresh',NULL,52,'Loader',CURRENT_TIMESTAMP),
# (5000005,'Priya','Iyer',27,'Analyst',CURRENT_TIMESTAMP);

# %% [markdown]
# ####2. Create Connection & Foreign Catalog
# **Foreign Catalog** is a Unity Catalog object that allows Databricks to reference and query metadata that lives outside Databricks, in an external metastore or database, without copying the data.
#
# **Connection**
# - Avoid hard-coding usernames/passwords in notebooks
# - Enable centralized governance via Unity Catalog
# - Allow multiple users and tables to reuse the same connection
# - Support SQL-based external access

# %%
# %sql
--Once for all activity
CREATE CONNECTION gcp_mysql_conn_wd36
TYPE mysql
OPTIONS (
  host '34.123.166.158',
  port '3306',
  user 'devuser',
  password 'Inceptez@123'
);

# %%
# %sql
--Activity to create a foreign catalog to refresh/refer the metadata
CREATE FOREIGN CATALOG gcp_mysql_fc_wd36
USING CONNECTION gcp_mysql_conn_wd36;

# %%
# %sql
DESCRIBE CONNECTION gcp_mysql_conn_wd36;

# %%
# %sql
show catalogs;

# %%
# %sql
select * from gcp_mysql_fc_wd36.logistics.shipments1;

# %% [markdown]
# ####3. Bronze table (Incremental ingestion)
# Let me simply use Foreign catalog as a data ingestion mechanism (rather than using traditional JDBC or third party tools to ingest data from Database).

# %%
# %sql
--Historical (Onetime) load (Depends on the business requirement)
--If my project requires entire 3 years shipment data from external database  or if we need only one year, apply filters accordingly..
CREATE TABLE IF NOT EXISTS catalog3_we47.schema3_we47.bronze_shipments1
USING DELTA
AS SELECT
  shipment_id,
  first_name,
  last_name,
  age,
  role,
  updated_at
FROM gcp_mysql_fc_wd36.logistics.shipments1;

# %%
# %sql
select * from catalog3_we47.schema3_we47.bronze_shipments1

# %% [markdown]
# Try to achieve SCD Type2 (just like that)<br>
# ####Insert data into the source Database table and run the incremental load,<br>
# INSERT INTO logistics.shipments1 VALUES (5000006,'Bala','Chander',35,'DE',CURRENT_TIMESTAMP);<br>
# ####Update data into the source Database table and run the incremental load,<br>
# update logistics.shipments1 set role='Databricks Data Engineer',updated_at=CURRENT_TIMESTAMP where shipment_id=5000006;

# %%
# %sql
    SELECT COALESCE(MAX(updated_at), '1970-01-01')
    FROM catalog3_we47.schema3_we47.bronze_shipments1

# %%
# %sql
--Incremental data ingestion/load of newly added/updated data is insert
--Extraction - We are doing Change Data Capture (CDC) (Inserted/updated)
--Load - We are doing Slowly Changing Dimension Type 2
INSERT INTO catalog3_we47.schema3_we47.bronze_shipments1
SELECT
  shipment_id,
  first_name,
  last_name,
  age,
  role,
  updated_at
FROM gcp_mysql_fc_wd36.logistics.shipments1
WHERE updated_at >
(
  SELECT COALESCE(MAX(updated_at), '1970-01-01')
  FROM catalog3_we47.schema3_we47.bronze_shipments1);

# %%
# %sql
    select * from catalog3_we47.schema3_we47.bronze_shipments1

# %%
    # %sql
    select *,row_number() over(partition by shipment_id order by updated_at desc) rno from catalog3_we47.schema3_we47.bronze_shipments1
    qualify rno>1;--latest version or history you can access

# %%
# %sql
    --Incremental load MERGE for SCD Type 1
    MERGE INTO catalog3_we47.schema3_we47.bronze_shipments1 AS target
    USING gcp_mysql_fc_wd36.logistics.shipments1 AS source
    ON target.shipment_id = source.shipment_id
    WHEN MATCHED THEN
      UPDATE SET
        target.first_name = source.first_name,
        target.last_name = source.last_name,
        target.age = source.age,
        target.role = source.role,
        target.updated_at = source.updated_at
    WHEN NOT MATCHED THEN
      INSERT (shipment_id, first_name, last_name, age, role, updated_at)
      VALUES (source.shipment_id, source.first_name, source.last_name, source.age, source.role, source.updated_at)
    WHEN NOT MATCHED BY SOURCE THEN
      DELETE;

# %%
# %sql
    delete from catalog3_we47.schema3_we47.bronze_shipments1 
    where shipment_id in (select tgt.shipment_id from catalog3_we47.schema3_we47.bronze_shipments1 tgt left join gcp_mysql_fc_wd36.logistics.shipments1 src on tgt.shipment_id=src.shipment_id where src.shipment_id is null);

# %%
    # %sql
    select * from catalog3_we47.schema3_we47.bronze_shipments1

# %% [markdown]
# **We will learn a complete VVV Important Cycle of CDC to CDF to SCD1 & SCD2 features when we move to Cloud, without too much of coding offered by Databricks**
