# %% [markdown]
# #Notebook to create and load data into databricks volume

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.mobile_metrics;

# %%
import requests
respone = requests.get("https://public.tableau.com/app/sample-data/mobile_os_usage.csv")
dbutils.fs.put("/Volumes/workspace/default/mobile_metrics/mobile_os_usage.csv",respone.text,overwrite=True)

# %%
ls /Volumes/workspace/default/mobile_metrics

# %%
# %fs head /Volumes/workspace/default/mobile_metrics/mobile_os_usage.csv

# %%
spark.read.csv("/Volumes/workspace/default/mobile_metrics/mobile_os_usage.csv").write.saveAsTable("mobile_os_usage")
